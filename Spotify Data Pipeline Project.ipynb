# %%
pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for spotipy from https://files.pythonhosted.org/packages/ea/35/304e456a471128aa4a776243558f43aee3444731ef8fc9bc8c351fddfdd8/spotipy-2.24.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for redis>=3.5.3 from https://files.pythonhosted.org/packages/3c/5f/fa26b9b2672cbe30e07d9a5bdf39cf16e3b80b42916757c5f92bca88e4ba/redis-5.2.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/261.5 kB ? eta -:--:--
#    ---------------------------------------  256.0/261.5 kB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 261.5/261.5 kB 3.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager=SpotifyClientCredentials(client_id="4cec0f4e12e141d8bac0eed11d5b5942",client_secret="e9a2944652db4b63a285ab360c83372d")

# %%
sp=spotipy.Spotify(client_credentials_manager = client_credentials_manager) #creates an object sp thorugh which we can extract
#the data from spotify API

# %%
playlist_link="https://open.spotify.com/playlist/5ABHKGoOzxkaa28ttQV9sE"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI) #extract all data from API and store in a vairable

# %%
data['items'][0]['track']['album']['id']
data['items'][0]['track']['album']['name']
data['items'][0]['track']['album']['release_date']
data['items'][0]['track']['album']['total_tracks']
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    album_element={'album_id':album_id,'album_name':album_name,'album_release_date':album_release_date,
                  'album_total_tracks':album_total_tracks,'album_url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'album_name': 'After Hours',
#   'album_release_date': '2020-03-20',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'album_name': '÷ (Deluxe)',
#   'album_release_date': '2017-03-03',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': '5658aM19fA3JVwTK6eQX70',
#   'album_name': 'Divinely Uninspired To A Hellish Extent',
#   'album_release_date': '2019-05-17',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'album_name': "Harry's House",
#   'album_release_date': '2022-05-20',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': '35s58BRTGAEWztPo9WqCIs',
# ...

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '1Xyo4u8uXC1ZmMpatF05PJ'

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#   'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#   'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'type': 'artist',
#   'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}]

# %%
artist_list=[]
for item in data['items']:
    for key,value in row.items():
        if key=="track":
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '0rvjqX7ttXeg3mTy8Xscbt',
#   'artist_name': 'Journey',
#   'external_url': 'https://api.spotify.com/v1/artists/0rvjqX7ttXeg3mTy8Xscbt'},
#  {'artist_id': '0rvjqX7ttXeg3mTy8Xscbt',
#   'artist_name': 'Journey',
#   'external_url': 'https://api.spotify.com/v1/artists/0rvjqX7ttXeg3mTy8Xscbt'},
#  {'artist_id': '0rvjqX7ttXeg3mTy8Xscbt',
#   'artist_name': 'Journey',
#   'external_url': 'https://api.spotify.com/v1/artists/0rvjqX7ttXeg3mTy8Xscbt'},
#  {'artist_id': '0rvjqX7ttXeg3mTy8Xscbt',
#   'artist_name': 'Journey',
#   'external_url': 'https://api.spotify.com/v1/artists/0rvjqX7ttXeg3mTy8Xscbt'},
#  {'artist_id': '0rvjqX7ttXeg3mTy8Xscbt',
#   'artist_name': 'Journey',
#   'external_url': 'https://api.spotify.com/v1/artists/0rvjqX7ttXeg3mTy8Xscbt'},
#  {'artist_id': '0rvjqX7ttXeg3mTy8Xscbt',
#   'artist_name': 'Journey',
#   'external_url': 'https://api.spotify.com/v1/artists/0rvjqX7ttXeg3mTy8Xscbt'},
#  {'artist_id': '0rvjqX7ttXeg3mTy8Xscbt',
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
# ...

# %%
song_list=[]
for row in data['items']:
    song_id=row['track']['id']
    song_name=row['track']['name']
    song_duration=row['track']['duration_ms']
    song_url=row['track']['external_urls']['spotify']
    song_popularity=row['track']['popularity']
    song_added=row['added_at']
    album_id=row['track']['album']['id']
    artist_id=row['track']['album']['artists'][0]['id']
    song_element={'song_id':song_id,'song_name':song_name,'song_duration':song_duration,'song_url':song_url,
                 'song_popularity':song_popularity,'song_added':song_added,'album_id':album_id,'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'song_name': 'Blinding Lights',
#   'song_duration': 200040,
#   'song_url': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b',
#   'song_popularity': 87,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7qiZfU4dY1lWllzX7mPBI3',
#   'song_name': 'Shape of You',
#   'song_duration': 233712,
#   'song_url': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3',
#   'song_popularity': 85,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '7qEHsqek33rTcFNT9PFqLf',
#   'song_name': 'Someone You Loved',
#   'song_duration': 182160,
#   'song_url': 'https://open.spotify.com/track/7qEHsqek33rTcFNT9PFqLf',
#   'song_popularity': 85,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '5658aM19fA3JVwTK6eQX70',
# ...

# %%
import pandas as pd

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                         album_name  \
# 0  4yP0hdKOZPNshxUOjY0cZj                                        After Hours
# 1  3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2  5658aM19fA3JVwTK6eQX70            Divinely Uninspired To A Hellish Extent
# 3  5r36AJ6VOJtp00oxSkBZ5h                                      Harry's House
# 4  35s58BRTGAEWztPo9WqCIs  Spider-Man: Into the Spider-Verse (Soundtrack ...
#
#   album_release_date  album_total_tracks  \
# 0         2020-03-20                  14
# 1         2017-03-03                  16
# 2         2019-05-17                  12
# 3         2022-05-20                  13
# 4         2018-12-14                  13
#
#                                            album_url
# 0  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2  https://open.spotify.com/album/5658aM19fA3JVwT...
# ...

# %%
album_df.info() #here release_date is in object so it has to be converted into datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            100 non-null    object
#  1   album_name          100 non-null    object
#  2   album_release_date  100 non-null    object
#  3   album_total_tracks  100 non-null    int64
#  4   album_url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   4yP0hdKOZPNshxUOjY0cZj                                        After Hours
# 1   3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2   5658aM19fA3JVwTK6eQX70            Divinely Uninspired To A Hellish Extent
# 3   5r36AJ6VOJtp00oxSkBZ5h                                      Harry's House
# 4   35s58BRTGAEWztPo9WqCIs  Spider-Man: Into the Spider-Verse (Soundtrack ...
# ..                     ...                                                ...
# 95  04m06KhJUuwe1Q487puIud                          Levitating (feat. DaBaby)
# 96  3TJz2UBNYJtlEly0sPeNrQ             The Thrill Of It All (Special Edition)
# 97  30ZRkfOK5G4fMm8vQ4q59b                          Walking Through the Night
# 98  1tA4JdOpNQUyutfQtmMesJ                                 In The Lonely Hour
# 99  5pfpXvoJtSIFrbPIoBEv3R                              The Essential Journey
#
# ...

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df=pd.DataFrame.from_dict(song_list)

# %%
song_df=song_df.drop_duplicates(subset=['song_id'])

# %%
album_df.head()
# Out:
#                  album_id                                         album_name  \
# 0  4yP0hdKOZPNshxUOjY0cZj                                        After Hours
# 1  3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2  5658aM19fA3JVwTK6eQX70            Divinely Uninspired To A Hellish Extent
# 3  5r36AJ6VOJtp00oxSkBZ5h                                      Harry's House
# 4  35s58BRTGAEWztPo9WqCIs  Spider-Man: Into the Spider-Verse (Soundtrack ...
#
#   album_release_date  album_total_tracks  \
# 0         2020-03-20                  14
# 1         2017-03-03                  16
# 2         2019-05-17                  12
# 3         2022-05-20                  13
# 4         2018-12-14                  13
#
#                                            album_url
# 0  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2  https://open.spotify.com/album/5658aM19fA3JVwT...
# ...

# %%
song_df.head()
# Out:
#                   song_id                                      song_name  \
# 0  0VjIjW4GlUZAMYd2vXMi3b                                Blinding Lights
# 1  7qiZfU4dY1lWllzX7mPBI3                                   Shape of You
# 2  7qEHsqek33rTcFNT9PFqLf                              Someone You Loved
# 3  4Dvkj6JhhA12EX05fT7y2e                                      As It Was
# 4  3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse
#
#    song_duration                                           song_url  \
# 0         200040  https://open.spotify.com/track/0VjIjW4GlUZAMYd...
# 1         233712  https://open.spotify.com/track/7qiZfU4dY1lWllz...
# 2         182160  https://open.spotify.com/track/7qEHsqek33rTcFN...
# 3         167303  https://open.spotify.com/track/4Dvkj6JhhA12EX0...
# 4         158040  https://open.spotify.com/track/3KkXRkHbMCARz0a...
#
#    song_popularity            song_added                album_id  \
# ...

# %%
artist_df.head()
# Out:
#                 artist_id artist_name  \
# 0  0rvjqX7ttXeg3mTy8Xscbt     Journey
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0rvjqX7ttXe...

# %%
album_df['album_release_date']=pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            92 non-null     object
#  1   album_name          92 non-null     object
#  2   album_release_date  92 non-null     datetime64[ns]
#  3   album_total_tracks  92 non-null     int64
#  4   album_url           92 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.3+ KB

# %%
song_df['song_added']=pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          100 non-null    object
#  1   song_name        100 non-null    object
#  2   song_duration    100 non-null    int64
#  3   song_url         100 non-null    object
#  4   song_popularity  100 non-null    int64
#  5   song_added       100 non-null    datetime64[ns, UTC]
#  6   album_id         100 non-null    object
#  7   artist_id        100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 7.0+ KB
